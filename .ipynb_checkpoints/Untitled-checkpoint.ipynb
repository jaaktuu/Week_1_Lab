# %% [markdown]
# # Lab 1 - Tuukka Jaakkola

# %% [markdown]
# ## Import Libraries

# %%
from plotnine import (
    ggplot,
    aes,
    geom_point,
    scale_x_continuous,
    scale_y_continuous,
    theme,
    scales,
    ylim,
)

import pandas as pd
import numpy as np
import math

# %% [markdown]
# ## Task 1

# %%
#Import Data
data1 = pd.read_csv(r'C:\Users\tuke-\Desktop\1_GSB544_Computing_and_Machine_Learning\Week_1_Lab\data\q1data.csv')
data1['income'] = data1['income'].apply(np.log2)
print(data1)

(ggplot(data1, aes(y='life_exp', x='income', fill = 'world_bank_region', size = 'population')) +
     geom_point() +
     scale_y_continuous(limits=(20,90)) +
     scale_x_continuous(breaks= [9,10,11,12,13,14,15,16,17], labels = ['0','500', '1000', '2000', '4000', '8000', '16k', '32k', '64k']) +
     theme(figure_size = (10,5))
)
# Out:
#         income  life_exp  population  year      country four_regions  \
# 0    10.899357      61.0  29200000.0  2010  Afghanistan         asia
# 1    13.438272      78.1   2950000.0  2010      Albania       europe
# 2    13.438272      74.7  36000000.0  2010      Algeria       africa
# 3    15.517300      81.9     84500.0  2010      Andorra       europe
# 4    12.906891      60.8  23400000.0  2010       Angola       africa
# ..         ...       ...         ...   ...          ...          ...
# 192  14.316282      75.4  28400000.0  2010    Venezuela     americas
# 193  12.385323      73.3  88000000.0  2010      Vietnam         asia
# 194  12.198445      67.8  23200000.0  2010        Yemen         asia
# 195  11.643856      57.5  13600000.0  2010       Zambia       africa
# 196  11.321928      54.4  12700000.0  2010     Zimbabwe       africa
#
#                   six_regions       eight_regions           world_bank_region
# ...
